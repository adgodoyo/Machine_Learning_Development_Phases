# %%
# Guardar varias bases, una con toda la población, otra con solo los padres, otra descartando a los menores de 2

# %%
import pandas as pd
import numpy as np

# %%
#Para que me muestre todas las columnas y no puntos suspensivos en vez de algunas
pd.options.display.max_columns = None

# %%
### abrimos base
#https://microdatos.dane.gov.co/index.php/catalog/643/get-microdata
dfP = pd.read_csv('DatosCenso_sin edición.csv')

# %%
dfP
# Out:
#          COD_ENCUESTAS         LLAVEHOG                 ID  \
# 0            900395117  900395117-1-1.0  900395117-1-1.0-1
# 1            900395117  900395117-1-1.0  900395117-1-1.0-2
# 2            900395117  900395117-1-1.0  900395117-1-1.0-3
# 3            900395117  900395117-1-1.0  900395117-1-1.0-4
# 4             15720976   15720976-1-1.0   15720976-1-1.0-1
# ...                ...              ...                ...
# 6589593      902201024  902201024-1-1.0  902201024-1-1.0-3
# 6589594      902201024  902201024-1-1.0  902201024-1-1.0-4
# 6589595      902201024  902201024-1-1.0  902201024-1-1.0-5
# 6589596      902201024  902201024-1-1.0  902201024-1-1.0-6
# 6589597      902201024  902201024-1-1.0  902201024-1-1.0-7
#
#                    COD_DANE_ANM  U_SECT_URB  UVA_USO_UNIDAD  VF_INTERNET  \
# 0        1100110000000084010103        8401               1          1.0
# 1        1100110000000084010103        8401               1          1.0
# ...

# %% [markdown]
# 1. ¿Cuántas personas en Bogotá tienen hijos nacidos vivos?

# %% [markdown]
# 2. ¿Cuántas personas en Bogotá están casadas o vivien en unión libre?

# %% [markdown]
# 3. ¿cuántas madres hay con al menos un hijo menor de 5 años?

# %% [markdown]
# 4. ¿cuant@s niñ@s de menos de 15 años no tienen internet?

# %% [markdown]
# 5. ¿cuántas personas fueron censadas en Bogotá que nacieron en otro país y hace un año vivían en otro país?

# %% [markdown]
# 6. ¿Cuántos hogares encabezados por parejas homosexuales hay en bogotá?
